# %% [markdown]
# <a href="https://colab.research.google.com/github/jasel0412/Simulaci-n/blob/main/Prueba_de_los_promedios_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Prueba de los promedios**
#
# Se realizara a continuació la prueba de los promedios de una lista de 100 numeros pseudoaleatrios,me diante una hipoteis nula
#
# $$H_0=\mu =\frac{1}{2} $$
# $$H_a\neq \frac{1}{2}$$
#
# para reafirmarlo se utilizara un criterio de mediante las hipotesis para un grado de confianza de la prueba donde
#
# $$\big|z_0\big|<z_{\frac{\alpha}{2}}$$
# $$z_0=\frac{(\bar x-\frac{1}{2})n^{\frac{1}{2}}} {\sqrt{\frac{1}{12}}}$$

# %%
import numpy as np
import statsmodels
import scipy.stats as st
D = [0.78961, 0.05230, 0.10699, 0.55877, 0.14151,
 0.76086, 0.12079, 0.27738, 0.65726, 0.79269,
 0.80548, 0.82654, 0.29453, 0.20852, 0.42989,
 0.58518, 0.98611, 0.34488, 0.34358, 0.11537,
 0.89898, 0.57880, 0.67621, 0.05010, 0.00121,
 0.28269, 0.73059, 0.70119, 0.18284, 0.49962,
 0.38618, 0.76910, 0.68334, 0.55170, 0.10850,
 0.79982, 0.45679, 0.21631, 0.87616, 0.55743,
 0.58962, 0.33216, 0.03185, 0.61168, 0.09264,
 0.69623, 0.17028, 0.05475, 0.91512, 0.76262,
 0.29931, 0.30861, 0.83358, 0.51781, 0.03272,
 0.57410, 0.26593, 0.85903, 0.43308, 0.35286,
 0.24000, 0.65559, 0.38507, 0.90829, 0.94187,
 0.93655, 0.88809, 0.81772, 0.36982, 0.19904,
 0.54325, 0.62400, 0.09133, 0.41678, 0.33954,
 0.58244, 0.85853, 0.88752, 0.33729, 0.15506,
 0.23949, 0.53559, 0.33381, 0.49383, 0.75103,
 0.19962, 0.65002, 0.74579, 0.79113, 0.63453,
 0.19147, 0.40644, 0.08128, 0.73435, 0.22724,
 0.22287, 0.07281, 0.64183, 0.44267, 0.72102]
n = len(D)#cuenta los numeros que se encuentran en la lista
print(n)
H_0 = 0.5#hipotesis nula
H_a =! 0.5#hipotesis adyacente
x_p = np.mean(D)#nos da la media de los datso de nuetras lista
alpha = float(input("ingrese el nivel de confianza para la prueba"))#introduciomos el grado de conifianza para la prueba
print(x_p)
if x_p == H_0:#primera pruaba para verificar si cumple las hiptesis
  print("Si son numeros aleatorios")
else:
  z_0 = (x_p-0.5)*(n**(1/2)) / (1/12)**(1/2)#definimos nuetra z_0
  z_0 = abs(z_0)#volvemos positivo el valor
  z_c = st.norm.ppf(1- alpha/2)#obtenemos nuestro valor alpha medios
  if z_c > z_0:#ultima prueba de comparacion para la prueba
    print("no se rechaza la hipotesis nula, son numeros aleatorios")
  else:
    print("se rechaza la hipotesis nula, no son numeros aleatorios")
  print(z_0)
  print(z_c)
# Out:
# 100
# ingrese el nivel de confianza para la prueba0.05
# 0.48234379999999993
# no se rechaza la hipotesis nula, son numeros aleatorios
# 0.6116287093719546
# 1.959963984540054
